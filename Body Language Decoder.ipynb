# %% [markdown]
# # 0. Install and Import Dependencies

# %%
#!pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\shalini sahu\anaconda3\lib\site-packages (0.10.8)
# Requirement already satisfied: opencv-python in c:\users\shalini sahu\anaconda3\lib\site-packages (4.8.1.78)
# Requirement already satisfied: pandas in c:\users\shalini sahu\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: scikit-learn in c:\users\shalini sahu\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: absl-py in c:\users\shalini sahu\anaconda3\lib\site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: numpy in c:\users\shalini sahu\anaconda3\lib\site-packages (from mediapipe) (1.19.5)
# Requirement already satisfied: opencv-contrib-python in c:\users\shalini sahu\anaconda3\lib\site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\shalini sahu\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\shalini sahu\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: matplotlib in c:\users\shalini sahu\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\shalini sahu\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\shalini sahu\anaconda3\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shalini sahu\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shalini sahu\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\shalini sahu\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\shalini sahu\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shalini sahu\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\shalini sahu\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\shalini sahu\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shalini sahu\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shalini sahu\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\shalini sahu\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shalini sahu\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shalini sahu\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\shalini sahu\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: pycparser in c:\users\shalini sahu\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Make Some Detections

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence = 0.5, min_tracking_confidence = 0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor feed (opencv give in BGR and we give it to holistic in RGB)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Set flag
        image.flags.writeable = False
        
        # Make Detections
        results = holistic.process(image)
        print(results)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Set flag to true
        image.flags.writeable = True
        
        # Recolor image back to BGR for rendering
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        cv2.imshow('Holistic Model Detection', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
results.face_landmarks.landmark[0].visibility 
#face_landmarks does not have visibility
# Out:
# 0.0

# %% [markdown]
# # 2. Capture Landmarks and Export to CSV

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.face_landmarks.landmark)+len(results.pose_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1,num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Meow"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence = 0.5, min_tracking_confidence = 0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor feed (opencv give in BGR and we give it to holistic in RGB)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Set flag
        image.flags.writeable = False
        
        # Make Detections
        results = holistic.process(image)
        print(results)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Set flag to true
        image.flags.writeable = True
        
        # Recolor image back to BGR for rendering
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row + face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)
        
        except:
            pass
        
        cv2.imshow('Holistic Model Detection', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
pose = results.pose_landmarks.landmark

# %%
np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten()
# Out:
# array([ 5.10370612e-01,  6.29374325e-01, -1.58020175e+00,  9.98420894e-01,
#         5.31267285e-01,  5.52480817e-01, -1.49080849e+00,  9.97033298e-01,
#         5.45428216e-01,  5.52579761e-01, -1.49131536e+00,  9.97109771e-01,
#         5.61750233e-01,  5.53869963e-01, -1.49150002e+00,  9.96223986e-01,
#         4.81420130e-01,  5.47601104e-01, -1.53161621e+00,  9.97774780e-01,
#         4.57742751e-01,  5.43676794e-01, -1.53175139e+00,  9.98212159e-01,
#         4.33669865e-01,  5.40406764e-01, -1.53253925e+00,  9.98242557e-01,
#         5.73606730e-01,  5.81644773e-01, -9.24269199e-01,  9.96394813e-01,
#         3.72058958e-01,  5.66945970e-01, -1.10213125e+00,  9.98988867e-01,
#         5.26858091e-01,  6.95764959e-01, -1.36121821e+00,  9.98663902e-01,
#         4.64494288e-01,  6.91552401e-01, -1.41651845e+00,  9.99370992e-01,
#         6.84373617e-01,  9.32427943e-01, -4.73716259e-01,  9.76314008e-01,
#         1.96992487e-01,  9.27246749e-01, -7.36707032e-01,  9.90224898e-01,
#         8.19874644e-01,  1.28115535e+00, -3.14416587e-01,  7.30523914e-02,
#         8.87187272e-02,  1.38132989e+00, -6.28533602e-01,  2.41830274e-01,
#         8.20111632e-01,  1.61867774e+00, -7.34217882e-01,  9.99951549e-03,
#         1.51909560e-01,  1.69906783e+00, -1.06391692e+00,  3.29317339e-02,
#         8.38711143e-01,  1.72417343e+00, -8.46967697e-01,  1.42449066e-02,
#         1.57520682e-01,  1.81515563e+00, -1.21824479e+00,  3.71760018e-02,
#         8.08931828e-01,  1.71806037e+00, -9.47726130e-01,  2.17879154e-02,
#         1.96090683e-01,  1.78318167e+00, -1.31217849e+00,  5.93044087e-02,
#         7.85075009e-01,  1.68033898e+00, -7.96651363e-01,  2.16245037e-02,
#         2.02625588e-01,  1.73813093e+00, -1.11761522e+00,  5.50903976e-02,
#         5.94931006e-01,  1.73739207e+00, -2.04793904e-02,  5.99206716e-04,
#         2.86437690e-01,  1.75010490e+00,  2.56159604e-02,  5.87387418e-04,
#         5.96461952e-01,  2.38242006e+00, -2.16994792e-01,  2.88319238e-03,
#         3.32782805e-01,  2.36195302e+00, -4.00336891e-01,  9.22426523e-04,
#         6.32768691e-01,  2.98614931e+00,  3.91455591e-01,  1.28355663e-04,
#         3.69072378e-01,  2.96499467e+00,  3.20435837e-02,  4.63841352e-05,
#         6.35062575e-01,  3.08632159e+00,  4.07152355e-01,  8.27717886e-05,
#         3.66219103e-01,  3.06814218e+00,  4.56672646e-02,  7.76656234e-05,
#         6.11613631e-01,  3.17298293e+00, -2.97615290e-01,  2.11991850e-04,
#         4.14621174e-01,  3.13516068e+00, -7.18716025e-01,  3.17574013e-04])

# %% [markdown]
# # 3.Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0  Happy  0.516837  0.593655 -1.030268  0.999174  0.541280  0.542670
# 1  Happy  0.515504  0.594665 -1.243569  0.999142  0.540228  0.542736
# 2  Happy  0.513698  0.595621 -1.214212  0.999137  0.539191  0.542767
# 3  Happy  0.512135  0.595917 -1.225901  0.999131  0.537877  0.542774
# 4  Happy  0.510594  0.597420 -1.234927  0.999069  0.536649  0.543153
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0.962684  0.998176  0.559309  ... -0.007044   0.0  0.568761  0.546741
# 1 -1.178270  0.998114  0.556344  ... -0.006576   0.0  0.569101  0.545683
# 2 -1.148389  0.998090  0.554313  ... -0.007382   0.0  0.565173  0.547314
# 3 -1.158810  0.998077  0.552373  ... -0.007978   0.0  0.564851  0.546155
# 4 -1.169905  0.997977  0.550756  ... -0.007937   0.0  0.564817  0.545881
#
#        z500  v500      x501      y501      z501  v501
# 0  0.010350   0.0  0.573993  0.542999  0.010903   0.0
# 1  0.011250   0.0  0.574271  0.541909  0.011800   0.0
# 2  0.009348   0.0  0.570377  0.543437  0.009792   0.0
# 3  0.009046   0.0  0.569905  0.542738  0.009466   0.0
# 4  0.009486   0.0  0.569838  0.542336  0.009970   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#      class        x1        y1        z1        v1        x2        y2  \
# 1470  Meow  0.507588  0.580113 -0.948286  0.999985  0.533556  0.528943
# 1471  Meow  0.489896  0.572359 -0.938100  0.999982  0.514063  0.520299
# 1472  Meow  0.480946  0.564367 -1.055431  0.999947  0.506163  0.513295
# 1473  Meow  0.468884  0.557261 -1.102754  0.999915  0.493922  0.508055
# 1474  Meow  0.468107  0.555280 -1.125252  0.999871  0.491610  0.506061
# 377 -0.016745   0.0  0.563535  0.693288 -0.017173   0.0
# 378 -0.015442   0.0  0.563925  0.693271 -0.015779   0.0
# ..        ...   ...       ...       ...       ...   ...
# 536  0.030309   0.0  0.584990  0.568463  0.031746   0.0
# 537  0.028240   0.0  0.585004  0.566979  0.029557   0.0
# 538  0.029199   0.0  0.585757  0.570099  0.030607   0.0
# 539  0.028583   0.0  0.585193  0.568302  0.029956   0.0
# 540  0.028986   0.0  0.586106  0.567645  0.030399   0.0
#
# [167 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 329     Victorious
# 1390          Meow
# 34           Happy
# 1328          Meow
# 415            Sad
#            ...
# 564          Bunny
# 836          Heart
# 76           Happy
# 95           Happy
# 576          Bunny
# Name: class, Length: 443, dtype: object

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Victorious', 'Meow', 'Happy', 'Meow', 'Sad', 'heart', 'Heart',
#        'Heart', 'Victorious', 'Sad', 'Heart', 'heart', 'Sad', 'Bunny',
#        'Bunny', 'Heart', 'heart', 'heart', 'Happy', 'Meow', 'Victorious',
#        'Victorious', 'Victorious', 'Sad', 'Happy', 'Sad', 'Heart',
#        'Bunny', 'Victorious', 'Bunny', 'Bunny', 'Heart', 'Meow', 'heart',
#        'Happy', 'Happy', 'heart', 'Bunny', 'Victorious', 'Meow',
#        'Victorious', 'Victorious', 'heart', 'Meow', 'Heart', 'Victorious',
#        'Bunny', 'Bunny', 'Heart', 'Victorious', 'Bunny', 'heart', 'Meow',
#        'Bunny', 'Bunny', 'heart', 'heart', 'Meow', 'Heart', 'Heart',
#        'Bunny', 'Heart', 'Happy', 'Bunny', 'Meow', 'heart', 'Happy',
#        'Heart', 'Meow', 'Happy', 'Sad', 'Heart', 'Bunny', 'Victorious',
#        'Bunny', 'Bunny', 'Meow', 'Bunny', 'Sad', 'Heart', 'Heart',
#        'Heart', 'Heart', 'Victorious', 'Heart', 'Victorious', 'heart',
#        'Bunny', 'Meow', 'Heart', 'Meow', 'Meow', 'Bunny', 'Happy',
#        'Heart', 'Heart', 'Heart', 'heart', 'Heart', 'Victorious', 'Meow',
#        'Sad', 'Sad', 'Bunny', 'Heart', 'Happy', 'Bunny', 'Happy', 'Sad',
#        'Meow', 'Victorious', 'Happy', 'Victorious', 'Victorious', 'Meow',
#        'Victorious', 'Meow', 'Victorious', 'Victorious', 'Bunny', 'Bunny',
#        'Heart', 'Sad', 'Bunny', 'Meow', 'Bunny', 'Sad', 'Sad', 'Meow',
#        'Sad', 'Meow', 'Happy', 'Bunny', 'heart', 'Heart', 'Happy',
#        'heart', 'Heart', 'Happy', 'Happy', 'Happy', 'Victorious', 'heart',
#        'Victorious', 'Bunny', 'Heart', 'Heart', 'heart', 'Heart', 'Bunny',
#        'Bunny', 'Meow', 'Victorious', 'Sad', 'Happy', 'Meow', 'Sad',
#        'Sad', 'Happy', 'Bunny', 'Happy', 'Sad', 'Happy', 'Victorious',
#        'Victorious', 'Happy', 'Bunny', 'Happy', 'heart', 'Sad', 'Bunny',
#        'Meow', 'Bunny', 'Heart', 'Bunny', 'Heart', 'Victorious', 'heart',
#        'Bunny', 'Meow', 'Meow', 'Happy', 'Victorious', 'heart', 'Bunny',
#        'Bunny', 'Heart', 'Heart', 'heart', 'heart', 'Sad', 'Meow',
#        'Victorious', 'heart', 'Victorious', 'Bunny', 'Heart', 'Heart',
#        'Sad', 'Happy', 'Heart', 'Bunny', 'Sad', 'Happy', 'Meow', 'Heart',
#        'heart', 'Sad', 'Heart', 'heart', 'Victorious', 'Heart', 'Happy',
#        'heart', 'Happy', 'Happy', 'Bunny', 'Bunny', 'Heart', 'Victorious',
#        'Heart', 'heart', 'Sad', 'Victorious', 'Heart', 'heart', 'Happy',
#        'Victorious', 'heart', 'Heart', 'Sad', 'Bunny', 'heart', 'Meow',
#        'heart', 'Sad', 'Sad', 'Heart', 'Bunny', 'Happy', 'Sad', 'Bunny',
#        'Bunny', 'Meow', 'Sad', 'heart', 'Sad', 'Heart', 'Meow', 'Meow',
#        'Bunny', 'Sad', 'heart', 'heart', 'Victorious', 'Victorious',
#        'Happy', 'Sad', 'heart', 'Meow', 'Bunny', 'Meow', 'Happy', 'Bunny',
#        'Heart', 'Bunny', 'Heart', 'Victorious', 'heart', 'Heart',
#        'Victorious', 'Victorious', 'Sad', 'Bunny', 'Meow', 'Heart',
#        'Victorious', 'Heart', 'Heart', 'Meow', 'Meow', 'Happy', 'Meow',
#        'Victorious', 'Victorious', 'Bunny', 'Happy', 'Happy',
#        'Victorious', 'Meow', 'Heart', 'Meow', 'Sad', 'Meow', 'Bunny',
#        'Happy', 'heart', 'heart', 'Bunny', 'Sad', 'Happy', 'heart',
#        'Happy', 'Bunny', 'Heart', 'Victorious', 'Meow', 'Sad', 'Happy',
#        'heart', 'Bunny', 'Happy', 'Meow', 'Victorious', 'Heart', 'Bunny',
#        'Victorious', 'heart', 'Heart', 'heart', 'Heart', 'Happy', 'Bunny',
#        'Happy', 'Sad', 'Happy', 'Bunny', 'Bunny', 'Victorious', 'Meow',
#        'Heart', 'heart', 'Happy', 'Bunny', 'Bunny', 'Meow', 'Meow',
#        'Happy', 'Sad', 'Victorious', 'Bunny', 'Bunny', 'Heart', 'Meow',
#        'Victorious', 'heart', 'Happy', 'Sad', 'Victorious', 'Bunny',
#        'Bunny', 'Meow', 'Heart', 'Bunny', 'Heart', 'Meow', 'heart',
#        'heart', 'Meow', 'Happy', 'Heart', 'Heart', 'Sad', 'Heart',
#        'Bunny', 'Heart', 'Bunny', 'Happy', 'Meow', 'Victorious', 'Heart',
#        'Heart', 'Victorious', 'Bunny', 'Heart', 'Bunny', 'Sad', 'Meow',
#        'Happy', 'Victorious', 'Meow', 'heart', 'Meow', 'Happy', 'Heart',
#        'Meow', 'Sad', 'Happy', 'Meow', 'Heart', 'Victorious', 'Bunny',
#        'Heart', 'heart', 'Meow', 'Heart', 'Meow', 'Victorious', 'Heart',
#        'heart', 'Bunny', 'Victorious', 'heart', 'heart', 'Heart', 'Sad',
#        'Bunny', 'Bunny', 'Heart', 'Sad', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Meow', 'heart', 'Meow', 'Happy', 'Bunny', 'Heart', 'Meow',
#        'Meow', 'Meow', 'Bunny', 'Meow', 'Bunny', 'Victorious', 'Sad',
#        'Heart', 'Heart', 'Heart', 'Victorious', 'Heart', 'Happy', 'Sad',
#        'Happy', 'Meow', 'Bunny', 'Heart', 'Happy', 'Happy', 'Bunny'],
#       dtype='<U10')

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9977426636568849
# rc 0.9977426636568849
# rf 0.9954853273137697
# gb 1.0

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Victorious', 'Meow', 'Happy', 'Meow', 'Sad', 'heart', 'Heart',
#        'Heart', 'Victorious', 'Sad', 'Heart', 'heart', 'Sad', 'Bunny',
#        'Bunny', 'Heart', 'heart', 'heart', 'Happy', 'Meow', 'Victorious',
#        'Victorious', 'Victorious', 'Sad', 'Happy', 'Sad', 'Heart',
#        'Bunny', 'Victorious', 'Bunny', 'Bunny', 'Heart', 'Meow', 'heart',
#        'Happy', 'Happy', 'heart', 'Bunny', 'Victorious', 'Meow',
#        'Victorious', 'Victorious', 'heart', 'Meow', 'Heart', 'Victorious',
#        'Bunny', 'Bunny', 'Heart', 'Victorious', 'Bunny', 'heart', 'Meow',
#        'Bunny', 'Bunny', 'heart', 'heart', 'Meow', 'Heart', 'Heart',
#        'Bunny', 'Heart', 'Happy', 'Bunny', 'Meow', 'heart', 'Happy',
#        'heart', 'Meow', 'Happy', 'Sad', 'Heart', 'Bunny', 'Victorious',
#        'Bunny', 'Bunny', 'Meow', 'Bunny', 'Sad', 'Heart', 'Heart',
#        'Heart', 'Heart', 'Victorious', 'Heart', 'Victorious', 'heart',
#        'Bunny', 'Meow', 'Heart', 'Meow', 'Meow', 'Bunny', 'Happy',
#        'Heart', 'Heart', 'Heart', 'heart', 'Heart', 'Victorious', 'Meow',
#        'Sad', 'Sad', 'Bunny', 'Heart', 'Happy', 'Bunny', 'Happy', 'Sad',
#        'Meow', 'Victorious', 'Happy', 'Victorious', 'Victorious', 'Meow',
#        'Victorious', 'Meow', 'Victorious', 'Victorious', 'Bunny', 'Bunny',
#        'Heart', 'Sad', 'Bunny', 'Meow', 'Bunny', 'Sad', 'Sad', 'Meow',
#        'Sad', 'heart', 'Happy', 'Bunny', 'heart', 'Heart', 'Happy',
#        'heart', 'Heart', 'Happy', 'Happy', 'Happy', 'Victorious', 'heart',
#        'Victorious', 'Heart', 'Heart', 'Heart', 'heart', 'Heart', 'Bunny',
#        'Bunny', 'Meow', 'Victorious', 'Sad', 'Happy', 'Meow', 'Sad',
#        'Sad', 'Happy', 'Bunny', 'Happy', 'Sad', 'Happy', 'Victorious',
#        'Victorious', 'Happy', 'Bunny', 'Happy', 'heart', 'Sad', 'Bunny',
#        'Meow', 'Bunny', 'Heart', 'Bunny', 'Heart', 'Victorious', 'heart',
#        'Bunny', 'Meow', 'Meow', 'Happy', 'Victorious', 'heart', 'Bunny',
#        'Bunny', 'Heart', 'Heart', 'heart', 'heart', 'Sad', 'Meow',
#        'Victorious', 'heart', 'Victorious', 'Bunny', 'Heart', 'Heart',
#        'Sad', 'Happy', 'Heart', 'Bunny', 'Sad', 'Happy', 'Meow', 'Heart',
#        'heart', 'Sad', 'Heart', 'heart', 'Victorious', 'Heart', 'Happy',
#        'heart', 'Happy', 'Happy', 'Bunny', 'Bunny', 'Heart', 'Victorious',
#        'Heart', 'heart', 'Sad', 'Victorious', 'Heart', 'heart', 'Happy',
#        'Victorious', 'heart', 'Heart', 'Sad', 'Bunny', 'heart', 'Meow',
#        'heart', 'Sad', 'Sad', 'Heart', 'Bunny', 'Happy', 'Sad', 'Bunny',
#        'Bunny', 'Meow', 'Sad', 'heart', 'Sad', 'Heart', 'Meow', 'Meow',
#        'Bunny', 'Sad', 'heart', 'heart', 'Victorious', 'Victorious',
#        'Happy', 'Sad', 'heart', 'Meow', 'Bunny', 'Meow', 'Happy', 'Bunny',
#        'Heart', 'Bunny', 'Heart', 'Victorious', 'heart', 'Heart',
#        'Victorious', 'Victorious', 'Sad', 'Bunny', 'Meow', 'Heart',
#        'Victorious', 'Heart', 'Heart', 'Meow', 'Meow', 'Happy', 'Meow',
#        'Victorious', 'Victorious', 'Bunny', 'Happy', 'Happy',
#        'Victorious', 'Meow', 'Heart', 'Meow', 'Sad', 'Meow', 'Bunny',
#        'Happy', 'heart', 'heart', 'Bunny', 'Sad', 'Happy', 'heart',
#        'Happy', 'Bunny', 'Heart', 'Victorious', 'Meow', 'Sad', 'Happy',
#        'heart', 'Bunny', 'Happy', 'Meow', 'Victorious', 'Heart', 'Bunny',
#        'Victorious', 'heart', 'Heart', 'heart', 'Heart', 'Happy', 'Bunny',
#        'Happy', 'Sad', 'Happy', 'Bunny', 'Bunny', 'Victorious', 'Meow',
#        'Heart', 'heart', 'Happy', 'Bunny', 'Bunny', 'Meow', 'Meow',
#        'Happy', 'Sad', 'Victorious', 'Bunny', 'Bunny', 'Heart', 'Meow',
#        'Victorious', 'heart', 'Happy', 'Sad', 'Victorious', 'Bunny',
#        'Bunny', 'Meow', 'Heart', 'Bunny', 'Heart', 'Meow', 'heart',
#        'heart', 'Meow', 'Happy', 'Heart', 'Heart', 'Sad', 'Heart',
#        'Bunny', 'Heart', 'Bunny', 'Happy', 'Meow', 'Victorious', 'Heart',
#        'Heart', 'Victorious', 'Bunny', 'Heart', 'Bunny', 'Sad', 'Meow',
#        'Happy', 'Victorious', 'Meow', 'heart', 'Meow', 'Happy', 'Heart',
#        'Meow', 'Sad', 'Happy', 'Meow', 'Heart', 'Victorious', 'Bunny',
#        'Heart', 'heart', 'Meow', 'Heart', 'Meow', 'Victorious', 'Heart',
#        'heart', 'Bunny', 'Victorious', 'heart', 'heart', 'Heart', 'Sad',
#        'Bunny', 'Bunny', 'Heart', 'Sad', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Meow', 'heart', 'Meow', 'Happy', 'Bunny', 'Heart', 'Meow',
#        'Meow', 'Meow', 'Bunny', 'Meow', 'Bunny', 'Victorious', 'Sad',
#        'Heart', 'Heart', 'Heart', 'Victorious', 'Heart', 'Happy', 'Sad',
#        'Happy', 'Meow', 'Bunny', 'Heart', 'Happy', 'Happy', 'Bunny'],
#       dtype=object)

# %%
y_test
# Out:
# 329     Victorious
# 1390          Meow
# 34           Happy
# 1328          Meow
# 415            Sad
#            ...
# 564          Bunny
# 836          Heart
# 76           Happy
# 95           Happy
# 576          Bunny
# Name: class, Length: 443, dtype: object

# %%
with open('body_language.pk2', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detection with Model

# %%
with open('body_language.pk2', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence = 0.5, min_tracking_confidence = 0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor feed (opencv give in BGR and we give it to holistic in RGB)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Set flag
        image.flags.writeable = False
        
        # Make Detections
        results = holistic.process(image)
        print(results)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Set flag to true
        image.flags.writeable = True
        
        # Recolor image back to BGR for rendering
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row + face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
        
        cv2.imshow('Holistic Model Detection', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
#
anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.02 0.06 0.   0.23 0.62 0.01 0.06]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.02 0.06 0.   0.23 0.62 0.01 0.06]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.02 0.06 0.   0.24 0.62 0.01 0.05]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.02 0.06 0.   0.24 0.62 0.01 0.05]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.01 0.04 0.   0.24 0.6  0.02 0.09]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.02 0.04 0.   0.26 0.56 0.01 0.11]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.02 0.04 0.   0.29 0.53 0.02 0.1 ]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.02 0.04 0.   0.28 0.56 0.03 0.07]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.02 0.05 0.   0.35 0.42 0.04 0.12]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.02 0.05 0.   0.34 0.48 0.04 0.07]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.03 0.04 0.   0.37 0.41 0.05 0.1 ]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.04 0.03 0.   0.31 0.52 0.02 0.08]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.04 0.03 0.   0.31 0.5  0.03 0.09]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.03 0.04 0.   0.28 0.55 0.02 0.08]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.04 0.05 0.   0.25 0.58 0.01 0.07]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.03 0.05 0.   0.25 0.6  0.01 0.06]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.03 0.09 0.   0.15 0.68 0.02 0.03]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.03 0.09 0.   0.14 0.69 0.02 0.03]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.03 0.09 0.   0.13 0.7  0.02 0.03]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.03 0.06 0.   0.12 0.76 0.   0.03]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.03 0.06 0.   0.12 0.73 0.02 0.04]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.03 0.06 0.   0.13 0.72 0.02 0.04]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.04 0.06 0.   0.1  0.78 0.   0.02]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.03 0.05 0.   0.04 0.86 0.   0.02]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.04 0.05 0.   0.04 0.86 0.   0.01]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.02 0.03 0.   0.03 0.91 0.   0.01]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Shalini Sahu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.01 0.02 0.   0.03 0.93 0.   0.01]
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sad [0.01 0.02 0.   0.04 0.91 0.   0.02]
